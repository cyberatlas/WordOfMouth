# %%
import epitran

# %%
epi = epitran.Epitran('eng-Latn')

# %%
phenome = epi.transliterate(u'This Shit is sick\n I like it')

# %%
list(phenome)
# Out:
# ['ð',
#  'ɪ',
#  's',
#  ' ',
#  'ʃ',
#  'ɪ',
#  't',
#  ' ',
#  'ɪ',
#  'z',
#  ' ',
#  's',
#  'ɪ',
#  'k',
#  '\n',
#  ' ',
#  'a',
#  'j',
#  ' ',
#  'l',
#  'a',
#  'j',
#  'k',
#  ' ',
#  'ɪ',
#  't']

# %%
with open('joe.txt','r') as file:
    data = file.read().replace('\n', '')

# %%
joePhenome = epi.transliterate(data)

# %%
joePhenome = joePhenome.split(' ')

# %%
data = data.split(' ')

# %%
list(zip(joePhenome, data))
# Out:
# [('hej', 'hey'),
#  ('fɹɛndz', 'friends'),
#  ('hawz', "how's"),
#  ('ɪt', 'it'),
#  ('ɡowɪŋ', 'going'),
#  ('ðɪs', 'this'),
#  ('ɛpəsowd', 'episode'),
#  ('ðə', 'the'),
#  ('pɑdkæst', 'podcast'),
#  ('bɹɔt', 'brought'),
#  ('tə', 'to'),
#  ('ju', 'you'),
#  ('baj', 'by'),
#  ('bʊt͡ʃɹ̩', 'butcher'),
#  ('bɑks', 'box'),
#  ('bʌt', 'but'),
#  ('jɔɹ', 'your'),
#  ('bɑks', 'box'),
#  ('mejks', 'makes'),
#  ('ɪt', 'it'),
#  ('izi', 'easy'),
#  ('fɔɹ', 'for'),
#  ('ju', 'you'),
#  ('tə', 'to'),
#  ('ɡɛt', 'get'),
#  ('haj-kwɑləti', 'high-quality'),
#  ('hjumənli', 'humanely'),
#  ('ɹejzd', 'raised'),
#  ('mit', 'meat'),
#  ('ðæt', 'that'),
#  ('ju', 'you'),
#  ('kæn', 'can'),
#  ('tɹʌst', 'trust'),
#  ('ɛvɹ̩i', 'every'),
#  ('mʌnθ', 'month'),
#  ('bʊt͡ʃɹ̩', 'butcher'),
#  ('bɑks', 'box'),
#  ('dɪlɪvɹ̩z', 'delivers'),
#  ('100%', '100%'),
#  ('ɡɹæs-fɛd', 'grass-fed'),
#  ('ænd', 'and'),
#  ('ɡɹæs-fɪnɪʃt', 'grass-finished'),
#  ('bif', 'beef'),
#  ('fɹi', 'free'),
#  ('ɹejnd͡ʒ', 'range'),
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
time = np.arange(0,len(audio)) / sfreq
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-35264febf1f5> in <module>
# ----> 1 time = np.arange(0,len(audio)) / sfreq
#
# NameError: name 'audio' is not defined

# %%
len(audio[:10000])
# Out:
# 10000

# %%
audio = audio[:10000]
time = time[:10000]

# %%
fig, ax = plt.subplots()
ax.plot(time,audio)
ax.set(xlabel="time",ylabel="Aplitude")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys

spf = wave.open('Joe_ad.wav','r')

#Extract Raw Audio from Wav File
signal = spf.readframes(-1)
print(signal)
signal = np.fromstring(signal, 'Int16')

plt.figure(figsize=(20,20))
plt.figure(1)
plt.title('Signal Wave...')
plt.plot(signal)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# /home/shiffy46/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   # This is added back by InteractiveShellApp.init_path()
# /home/shiffy46/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   # This is added back by InteractiveShellApp.init_path()
